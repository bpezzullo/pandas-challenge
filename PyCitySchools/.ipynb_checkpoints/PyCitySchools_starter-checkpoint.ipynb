# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
school_count = school_data_complete["school_name"].nunique()
student_count = school_data_complete["student_name"].nunique()
math_pass = (school_data_complete[school_data_complete["math_score"] > 70].count() /student_count) * 100
reading_pass = (school_data_complete[school_data_complete["reading_score"] > 70].count() /student_count) * 100
total_pass = (school_data_complete[(school_data_complete["math_score"] > 70) & (school_data_complete["reading_score"] > 70)].count() /student_count) * 100


district_summary = pd.DataFrame({"School Count":school_data_complete["school_name"].nunique(),
                                "Student Count" : school_data_complete["student_name"].nunique(),
                                "Total Budget" : school_data_complete["budget"].sum(),
                                "Average Math Score" : school_data_complete["math_score"].mean(),
                                "Average Reading Score" : school_data_complete["reading_score"].mean(),
                                "Percentage of passing Math scores" : math_pass.max(),
                                "Percentage of passing Reading scores" : reading_pass.max(),
                                "Percentage overall passing" : total_pass.max()                                
                                },index=[0])
district_summary["Percentage of passing Reading scores"] = district_summary["Percentage of passing Reading scores"].map("{:.2f} %".format)
district_summary["Percentage of passing Math scores"] = district_summary["Percentage of passing Math scores"].map("{:.2f} %".format)
district_summary["Percentage overall passing"] = district_summary["Percentage overall passing"].map("{:.2f} %".format)
district_summary["Average Reading Score"] = district_summary["Average Reading Score"].map("{:.2f}".format)
district_summary["Average Math Score"] = district_summary["Average Math Score"].map("{:.2f}".format)
district_summary["Total Budget"] = district_summary["Total Budget"].map("${:,}".format)
district_summary
# Out:
#    School Count  Student Count     Total Budget Average Math Score  \
# 0            15          32715  $82,932,329,558              78.99
#
#   Average Reading Score Percentage of passing Math scores  \
# 0                 81.88                           86.68 %
#
#   Percentage of passing Reading scores Percentage overall passing
# 0                              99.34 %                    72.80 %

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
school_grp = school_data_complete.groupby("school_name")
#math_pass = school_grp.loc[school_grp["math_score"] > 70 , :].count()

def reading_calc(reading):
    if (reading > 70): 
        return  True
    else:
        return False
    
reading_pass = school_grp[["reading_score"]].apply(lambda x : reading_calc(x['reading_score']),axis=1)
#total_pass = school_data_complete[(school_data_complete["school_name","math_score"] > 70) & (school_data_complete["school_name","reading_score"] > 70)].count() 
reading_pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     735             try:
# --> 736                 result = self._python_apply_general(f)
#     737             except TypeError:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     751     def _python_apply_general(self, f):
# --> 752         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     753
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
print(school_names)
# Out:
# ['Huang High School', 'Figueroa High School', 'Shelton High School', 'Hernandez High School', 'Griffin High School', 'Wilson High School', 'Cabrera High School', 'Bailey High School', 'Holden High School', 'Pena High School', 'Wright High School', 'Rodriguez High School', 'Johnson High School', 'Ford High School', 'Thomas High School']

# %%
school_names = school_data_complete['school_name'].unique().tolist()

school_data_group = school_data_complete.groupby("school_name")

for n in school_names: 
    series = school_data_complete.loc[n , :]

print(series)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Huang High School'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-397d9ce52e5e> in <module>
#       4
#       5 for n in school_names:
# ----> 6     series = school_data_complete.loc[n , :]
#       7
#       8 print(series)
#
# ...

# %%
def scores_calc(math,reading):
    if (math > 70 and reading > 70): 
        return  1
    else:
        return  
        
school_data_complete['combined_score'] = school_data_complete.apply(lambda x: scores_calc(x['math_score'],x['reading_score']),axis=1)
school_data_complete['math above 70'] = school_data_complete.loc[school_data_complete["math_score"] > 70, 'math_score']
school_data_complete['read above 70'] = school_data_complete.loc[school_data_complete["reading_score"] > 70, 'reading_score']
school_data_complete['read2 above 70'] = np.where(school_data_complete['reading_score'] > 70, 0, 1)
school_data_complete
# Out:
# C:\Users\bpezz\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   # Remove the CWD from sys.path while we load stuff.
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# ...

# %%
school_summary_grp = school_data_complete.groupby(['school_name']).agg({'budget': sum,
                                                                        'student_name':'count',
                                                                        'math_score' : ['mean','count'],
                                                                        'reading_score' : ['mean','count'],
                                                                        'combined_score' : ['count'],
                                                                        'math above 70' : ['count'],
                                                                        'read2 above 70' : ['sum','count']
                                                                        })



#purchase_count = purchase_count.rename(columns = {'count' :'Purchase Count',
#                                                  'Price':'','mean':'Item Price',
#                                                  'sum':'Total Purchase Value'})
#purchase_count = purchase_count.sort_values([('','Purchase Count')],ascending=False)
#purchase_count[('','Item Price')] = purchase_count[('','Item Price')].map("${:.2f}".format)
#purchase_count2 = purchase_count.copy()
#purchase_count[('','Total Purchase Value')] = purchase_count[('','Total Purchase Value')].map("${:.2f}".format)
school_summary_grp['combined_score','count']=school_summary_grp['combined_score','count'] / school_summary_grp['reading_score','count'] * 100
school_summary_grp['math above 70','count']=school_summary_grp['math above 70','count'] / school_summary_grp['math_score','count'] * 100
school_summary_grp['read above 70']=(school_summary_grp['read2 above 70','count'] / school_summary_grp['read2 above 70','sum']) * 100

school_summary_grp
#school_test summary = pd.DataFrame()
# Out:
#                             budget student_name math_score        \
#                                sum        count       mean count
# school_name
# Bailey High School     15549641728         4976  77.048432  4976
# Cabrera High School     2009159448         1858  83.061895  1858
# Figueroa High School    5557128039         2949  76.711767  2949
# Ford High School        4831365924         2739  77.102592  2739
# Griffin High School     1346890000         1468  83.351499  1468
# Hernandez High School  14007062700         4635  77.289752  4635
# Holden High School       105933149          427  83.803279   427
# Huang High School       5573322295         2917  76.629414  2917
# Johnson High School    14733628650         4761  77.072464  4761
# Pena High School         563595396          962  83.839917   962
# Rodriguez High School  10186904637         3999  76.842711  3999
# Shelton High School     1860672600         1761  83.359455  1761
# ...

# %%
df['color'] = np.where(df['Set']=='Z', 'green', 'red')

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [raw]
# * Sort and display the top five performing schools by % overall passing.

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
